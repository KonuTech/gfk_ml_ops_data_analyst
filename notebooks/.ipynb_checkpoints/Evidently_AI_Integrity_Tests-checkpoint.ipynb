# %% [markdown]
# https://evidentlyai.com/blog/evidently-test-based-ml-monitoring

# %%
import os
import json
import pandas as pd
from pandas_profiling import ProfileReport

# %%
INPUT_PATH="input"
OUTPUT_PATH="output"
CONFIG_PATH="config"

INPUT_DATA="test_data2"
INPUT_DATA_CONFIG="input_config"
OUTPUT_DATA="output"

INPUT_EXTENSION="csv"
INPUT_CONFIG_EXTENSION="json"
OUTPUT_EXTENSION="csv"

INPUT_FILE=f"{INPUT_DATA}.{INPUT_EXTENSION}"
INPUT_CONFIG_FILE=f"{INPUT_DATA_CONFIG}.{INPUT_CONFIG_EXTENSION}"
OUTPUT_FILE=f"{OUTPUT_DATA}.{OUTPUT_EXTENSION}"

INPUT_ABS_APTH=os.path.abspath(os.path.join(INPUT_PATH, INPUT_FILE))
INPUT_FILE_CONFIG=os.path.abspath(os.path.join(CONFIG_PATH, INPUT_CONFIG_FILE))
OUTPUT_ABS_APTH=os.path.abspath(os.path.join(OUTPUT_PATH, OUTPUT_FILE))

# %%
with open(INPUT_FILE_CONFIG, encoding='utf-8') as f:
    config = json.load(f)

# %%
df = pd.read_csv(
    INPUT_ABS_APTH,
    sep=config['INPUTS']['SEPARATOR'],
    encoding=config['INPUTS']['ENCODING'],
    infer_datetime_format=True,
    parse_dates=config['INPUTS']['DATE_COLUMNS'],
    engine="c",
    low_memory=False,
    skipinitialspace=True,
    dtype=config['INPUTS']['DTYPE']
)

# %%
import matplotlib as plt
from evidently.dashboard import Dashboard
from evidently.options import DataDriftOptions
from evidently.pipeline.column_mapping import ColumnMapping
from evidently.dashboard.tabs import DataDriftTab, CatTargetDriftTab, ClassificationPerformanceTab

from evidently.test_suite import TestSuite
from evidently.tests import *
from evidently.test_preset import NoTargetPerformance, DataQuality, DataStability, DataDrift

plt.rcParams.update({'figure.max_open_warning': 0})

def get_test_report(data_frame, target, prediction, datetime,
                    categorical_fatures, columns_to_exclude, breaking_point_dt):
    """
    :param data_frame:
    :param target:
    :param prediction:
    :param datetime:
    :param categorical_fatures:
    :param columns_to_exclude:
    :param breaking_point_dt:
    :return:
    """

    data_integrity_dataset_tests = TestSuite(tests=[
         TestNumberOfRows()
    ])

    cf = categorical_fatures

    df_column_mapping = ColumnMapping()
    df_column_mapping.categorical_features = cf
    df_column_mapping.target = target
    df_column_mapping.prediction = prediction
    df_column_mapping.datetime = datetime

    data_frame = data_frame.drop(columns=columns_to_exclude)
    data_frame.sort_values(by=[datetime], inplace=True)
    data_frame.reset_index(drop=True, inplace=True)
    data_frame['week_number'] = data_frame[datetime].dt.strftime('%Y%V').astype(int)

    reference = data_frame[data_frame[datetime] < breaking_point_dt]
    reference['week_number'] = reference['week_number'].apply(str)
    print(f"\n REFERENCE SHAPE: {reference.shape}")

    current = data_frame[data_frame[datetime] >= breaking_point_dt]
    current['week_number'] = current['week_number'].apply(str)
    print(f"\n CURRENT SHAPE: {current.shape}")

    # data_integrity_dataset_tests.calculate(reference, current, column_mapping=df_column_mapping)
    data_integrity_dataset_tests.run(reference_data=reference[:100], current_data=current[:100])
    # data_integrity_dataset_tests.save("output/reports/target_drift/000000_target_drift_report.html")
    # print("PRODUCED A CHART OF TARGET DRIFT GLOBAL")
    
    return data_integrity_dataset_tests

# %%
data_integrity_dataset_tests = get_test_report(
        data_frame=df,
        target=config['MODEL']['TARGET'],
        prediction=config['MODEL']['PREDICTION'],
        datetime=config['MODEL']['DATETIME'],
        categorical_fatures=config['INPUTS']['CATEGORICAL_FEATURES'],
        columns_to_exclude=config['OUTPUTS']['COLUMNS_TO_EXCLUDE'],
        breaking_point_dt=config['OUTPUTS']['BREAKING_POINT_DT']
    )
# Out:
#  REFERENCE SHAPE: (18630, 10)
#
#  CURRENT SHAPE: (1067, 10)

# %%
data_integrity_dataset_tests
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_ead5f32bb8fa46328206dd24e42863a1 = {"name": "Test Suite", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "1", "label": "Tests"}, {"value": "1", "label": "Success"}, {"value": "0", "label": "Warning"}, {"value": "0", "label": "Fail"}, {"value": "0", "label": "Error"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "test_suite", "title": "", "size": 2, "id": "", "details": "", "alertsPosition": null, "alertStats": null, "params": {"tests": [{"title": "Number of Rows", "description": "The number of rows is 100. The test threshold is eq=100 \u00b1 10.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "Number of Rows"}}], "testGroupTypes": [{"id": "by_feature", "title": "By feature", "values": [{"id": "no group", "title": "Dataset-level tests", "description": "Some tests cannot be grouped by feature", "sort_index": 0, "severity": null}]}, {"id": "test_group", "title": "By test group", "values": [{"id": "no group", "title": "Ungrouped", "description": "Some tests don\u2019t belong to any group under the selected condition", "sort_index": 0, "severity": null}, {"id": "data_drift", "title": "Data Drift", "description": "", "sort_index": 0, "severity": null}, {"id": "data_integrity", "title": "Data Integrity", "description": "", "sort_index": 0, "severity": null}, {"id": "data_quality", "title": "Data Quality", "description": "", "sort_index": 0, "severity": null}, {"id": "regression", "title": "Regression", "description": "", "sort_index": 0, "severity": null}, {"id": "classification", "title": "Classification", "description": "", "sort_index": 0, "severity": null}]}, {"id": "test_type", "title": "By test type", "values": []}, {"id": "by_class", "title": "By class", "values": []}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}]};
#     var additional_graphs_evidently_dashboard_ead5f32bb8fa46328206dd24e42863a1 = {};
# </script>
# <script>
# function domReady(fn) {
#   // If we're early to the party
#   document.addEventListener("DOMContentLoaded", fn);
#   // If late; I mean on time.
#   if (document.readyState === "interactive" || document.readyState === "complete" ) {
#     fn();
#   }
# }
#
# domReady(function () {
#     requirejs(["evidently"], function(ev) {
#         drawDashboard(evidently_dashboard_ead5f32bb8fa46328206dd24e42863a1,
#         new Map(Object.entries(additional_graphs_evidently_dashboard_ead5f32bb8fa46328206dd24e42863a1)),
#         "root_evidently_dashboard_ead5f32bb8fa46328206dd24e42863a1");
#     },
#     function(err) {
#         $("#root_evidently_dashboard_ead5f32bb8fa46328206dd24e42863a1").innerHTML = "Failed to load";
#     })
# });
# </script>
# <div class="reset-this-parent" id="root_evidently_dashboard_ead5f32bb8fa46328206dd24e42863a1">Loading...</div>

# %%
pp.pprint(data_integrity_dataset_tests.json())
# Out:
# ('{"version": "0.1.56.dev0", "datetime": "2022-08-28T13:04:51.368795", '
#  '"tests": [{"name": "Share of Drifted Features", "description": "The drift is '
#  'detected for 80% features (8 out of 10). The test threshold is lt=3", '
#  '"status": "SUCCESS", "group": "data_drift", "parameters": {"condition": '
#  '{"lt": 3}, "features": {"class_acctual": {"stattest": "Z-test p_value", '
#  '"score": 0.645, "threshold": 0.05, "data_drift": "Not Detected"}, '
#  '"predict_automatch": {"stattest": "Z-test p_value", "score": 0.871, '
#  '"threshold": 0.05, "data_drift": "Not Detected"}, "brand_id": {"stattest": '
#  '"chi-square p_value", "score": 0.0, "threshold": 0.05, "data_drift": '
#  '"Detected"}, "country_id_n": {"stattest": "chi-square p_value", "score": '
#  '0.0, "threshold": 0.05, "data_drift": "Detected"}, "delivery_type_id": '
#  '{"stattest": "chi-square p_value", "score": 0.0, "threshold": 0.05, '
#  '"data_drift": "Detected"}, "period_end_date": {"stattest": "chi-square '
#  'p_value", "score": 0.0, "threshold": 0.05, "data_drift": "Detected"}, '
#  '"prod_gr_id": {"stattest": "chi-square p_value", "score": 0.0, "threshold": '
#  '0.05, "data_drift": "Detected"}, "retailer_id": {"stattest": "chi-square '
#  'p_value", "score": 0.0, "threshold": 0.05, "data_drift": "Detected"}, '
#  '"translated_when": {"stattest": "chi-square p_value", "score": 0.0, '
#  '"threshold": 0.05, "data_drift": "Detected"}, "week_number": {"stattest": '
#  '"chi-square p_value", "score": 0.0, "threshold": 0.05, "data_drift": '
#  '"Detected"}}}}, {"name": "Column Types", "description": "The number of '
#  'columns with a type mismatch is 0 out of 10.", "status": "SUCCESS", "group": '
#  '"data_integrity", "parameters": {"columns": [{"column_name": "brand_id", '
#  '"actual_type": "object_", "expected_type": "object_"}, {"column_name": '
#  '"class_acctual", "actual_type": "float64", "expected_type": "float64"}, '
#  '{"column_name": "country_id_n", "actual_type": "object_", "expected_type": '
#  '"object_"}, {"column_name": "delivery_type_id", "actual_type": "object_", '
#  '"expected_type": "object_"}, {"column_name": "period_end_date", '
#  '"actual_type": "Timestamp", "expected_type": "Timestamp"}, {"column_name": '
#  '"predict_automatch", "actual_type": "float64", "expected_type": "float64"}, '
#  '{"column_name": "prod_gr_id", "actual_type": "object_", "expected_type": '
#  '"object_"}, {"column_name": "retailer_id", "actual_type": "object_", '
#  '"expected_type": "object_"}, {"column_name": "translated_when", '
#  '"actual_type": "Timestamp", "expected_type": "Timestamp"}, {"column_name": '
#  '"week_number", "actual_type": "object_", "expected_type": "object_"}]}}, '
#  '{"name": "Test Share Of Null Values In Column", "description": "Share of '
#  'null values in **brand_id** is 0.0. The test threshold is lte=0 \\u00b1 '
#  '1e-12.", "status": "SUCCESS", "group": "data_integrity", "parameters": '
#  '{"condition": {"lte": {"value": 0.0, "relative": 0.1, "absolute": 1e-12}}, '
#  '"share_of_null_values": 0.0, "column_name": "brand_id"}}, {"name": "Test '
#  'Share Of Null Values In Column", "description": "Share of null values in '
#  '**country_id_n** is 0.02. The test threshold is lte=0.07 \\u00b1 0.007.", '
#  '"status": "SUCCESS", "group": "data_integrity", "parameters": {"condition": '
#  '{"lte": {"value": 0.07, "relative": 0.1, "absolute": 1e-12}}, '
#  '"share_of_null_values": 0.02, "column_name": "country_id_n"}}, {"name": '
#  '"Test Share Of Null Values In Column", "description": "Share of null values '
#  'in **delivery_type_id** is 0.02. The test threshold is lte=0.07 \\u00b1 '
#  '0.007.", "status": "SUCCESS", "group": "data_integrity", "parameters": '
#  '{"condition": {"lte": {"value": 0.07, "relative": 0.1, "absolute": 1e-12}}, '
#  '"share_of_null_values": 0.02, "column_name": "delivery_type_id"}}, {"name": '
#  '"Test Share Of Null Values In Column", "description": "Share of null values '
#  'in **period_end_date** is 0.0. The test threshold is lte=0 \\u00b1 1e-12.", '
#  '"status": "SUCCESS", "group": "data_integrity", "parameters": {"condition": '
#  '{"lte": {"value": 0.0, "relative": 0.1, "absolute": 1e-12}}, '
#  '"share_of_null_values": 0.0, "column_name": "period_end_date"}}, {"name": '
#  '"Test Share Of Null Values In Column", "description": "Share of null values '
#  'in **prod_gr_id** is 0.0. The test threshold is lte=0 \\u00b1 1e-12.", '
#  '"status": "SUCCESS", "group": "data_integrity", "parameters": {"condition": '
#  '{"lte": {"value": 0.0, "relative": 0.1, "absolute": 1e-12}}, '
#  '"share_of_null_values": 0.0, "column_name": "prod_gr_id"}}, {"name": "Test '
#  'Share Of Null Values In Column", "description": "Share of null values in '
#  '**retailer_id** is 0.0. The test threshold is lte=0 \\u00b1 1e-12.", '
#  '"status": "SUCCESS", "group": "data_integrity", "parameters": {"condition": '
#  '{"lte": {"value": 0.0, "relative": 0.1, "absolute": 1e-12}}, '
#  '"share_of_null_values": 0.0, "column_name": "retailer_id"}}, {"name": "Test '
#  'Share Of Null Values In Column", "description": "Share of null values in '
#  '**translated_when** is 0.0. The test threshold is lte=0 \\u00b1 1e-12.", '
#  '"status": "SUCCESS", "group": "data_integrity", "parameters": {"condition": '
#  '{"lte": {"value": 0.0, "relative": 0.1, "absolute": 1e-12}}, '
#  '"share_of_null_values": 0.0, "column_name": "translated_when"}}, {"name": '
#  '"Test Share Of Null Values In Column", "description": "Share of null values '
#  'in **week_number** is 0.0. The test threshold is lte=0 \\u00b1 1e-12.", '
#  '"status": "SUCCESS", "group": "data_integrity", "parameters": {"condition": '
#  '{"lte": {"value": 0.0, "relative": 0.1, "absolute": 1e-12}}, '
#  '"share_of_null_values": 0.0, "column_name": "week_number"}}, {"name": "Test '
#  'Share Of Null Values In Column", "description": "Share of null values in '
#  '**class_acctual** is 0.0. The test threshold is lte=0 \\u00b1 1e-12.", '
#  '"status": "SUCCESS", "group": "data_integrity", "parameters": {"condition": '
#  '{"lte": {"value": 0.0, "relative": 0.1, "absolute": 1e-12}}, '
#  '"share_of_null_values": 0.0, "column_name": "class_acctual"}}, {"name": '
#  '"Test Share Of Null Values In Column", "description": "Share of null values '
#  'in **predict_automatch** is 0.03. The test threshold is lte=0 \\u00b1 '
#  '1e-12.", "status": "FAIL", "group": "data_integrity", "parameters": '
#  '{"condition": {"lte": {"value": 0.0, "relative": 0.1, "absolute": 1e-12}}, '
#  '"share_of_null_values": 0.03, "column_name": "predict_automatch"}}, {"name": '
#  '"Share of Out-of-Range Values", "description": "The share of values out of '
#  'range in the column **class_acctual** is 0 (0 out of 100).  The test '
#  'threshold is eq=0 \\u00b1 1e-12.", "status": "SUCCESS", "group": '
#  '"data_quality", "parameters": {"condition": {"eq": {"value": 0, "relative": '
#  '1e-06, "absolute": 1e-12}}, "left": null, "right": null, '
#  '"share_not_in_range": 0.0}}, {"name": "Share of Out-of-Range Values", '
#  '"description": "The share of values out of range in the column '
#  '**predict_automatch** is 0 (0 out of 97).  The test threshold is eq=0 '
#  '\\u00b1 1e-12.", "status": "SUCCESS", "group": "data_quality", "parameters": '
#  '{"condition": {"eq": {"value": 0, "relative": 1e-06, "absolute": 1e-12}}, '
#  '"left": null, "right": null, "share_not_in_range": 0.0}}, {"name": "Share of '
#  'Out-of-List Values", "description": "The share of values out of list in the '
#  'column **brand_id** is 0.59 (59 out of 100). The test threshold is eq=0 '
#  '\\u00b1 1e-12.", "status": "FAIL", "group": "data_quality", "parameters": '
#  '{"condition": {"eq": {"value": 0, "relative": 1e-06, "absolute": 1e-12}}, '
#  '"values": null, "share_not_in_list": 0.59}}, {"name": "Share of Out-of-List '
#  'Values", "description": "The share of values out of list in the column '
#  '**country_id_n** is 0.45 (45 out of 100). The test threshold is eq=0 \\u00b1 '
#  '1e-12.", "status": "FAIL", "group": "data_quality", "parameters": '
#  '{"condition": {"eq": {"value": 0, "relative": 1e-06, "absolute": 1e-12}}, '
#  '"values": null, "share_not_in_list": 0.45}}, {"name": "Share of Out-of-List '
#  'Values", "description": "The share of values out of list in the column '
#  '**delivery_type_id** is 0.79 (79 out of 100). The test threshold is eq=0 '
#  '\\u00b1 1e-12.", "status": "FAIL", "group": "data_quality", "parameters": '
#  '{"condition": {"eq": {"value": 0, "relative": 1e-06, "absolute": 1e-12}}, '
#  '"values": null, "share_not_in_list": 0.79}}, {"name": "Share of Out-of-List '
#  'Values", "description": "The share of values out of list in the column '
#  '**period_end_date** is 1 (100 out of 100). The test threshold is eq=0 '
#  '\\u00b1 1e-12.", "status": "FAIL", "group": "data_quality", "parameters": '
#  '{"condition": {"eq": {"value": 0, "relative": 1e-06, "absolute": 1e-12}}, '
#  '"values": null, "share_not_in_list": 1.0}}, {"name": "Share of Out-of-List '
#  'Values", "description": "The share of values out of list in the column '
#  '**prod_gr_id** is 0 (0 out of 100). The test threshold is eq=0 \\u00b1 '
#  '1e-12.", "status": "SUCCESS", "group": "data_quality", "parameters": '
#  '{"condition": {"eq": {"value": 0, "relative": 1e-06, "absolute": 1e-12}}, '
#  '"values": null, "share_not_in_list": 0.0}}, {"name": "Share of Out-of-List '
#  'Values", "description": "The share of values out of list in the column '
#  '**retailer_id** is 0.1 (10 out of 100). The test threshold is eq=0 \\u00b1 '
#  '1e-12.", "status": "FAIL", "group": "data_quality", "parameters": '
#  '{"condition": {"eq": {"value": 0, "relative": 1e-06, "absolute": 1e-12}}, '
#  '"values": null, "share_not_in_list": 0.1}}, {"name": "Share of Out-of-List '
#  'Values", "description": "The share of values out of list in the column '
#  '**translated_when** is 1 (100 out of 100). The test threshold is eq=0 '
#  '\\u00b1 1e-12.", "status": "FAIL", "group": "data_quality", "parameters": '
#  '{"condition": {"eq": {"value": 0, "relative": 1e-06, "absolute": 1e-12}}, '
#  '"values": null, "share_not_in_list": 1.0}}, {"name": "Share of Out-of-List '
#  'Values", "description": "The share of values out of list in the column '
#  '**week_number** is 1 (100 out of 100). The test threshold is eq=0 \\u00b1 '
#  '1e-12.", "status": "FAIL", "group": "data_quality", "parameters": '
#  '{"condition": {"eq": {"value": 0, "relative": 1e-06, "absolute": 1e-12}}, '
#  '"values": null, "share_not_in_list": 1.0}}, {"name": "Mean Value Stability", '
#  '"description": "The mean value of the column **class_acctual** is 0.68. The '
#  'expected range is from -0.21 to 1.63", "status": "SUCCESS", "group": '
#  '"data_quality", "parameters": {"column_name": "class_acctual", "n_sigmas": '
#  '2, "current_mean": 0.68, "reference_mean": 0.71, "reference_std": 0.46}}, '
#  '{"name": "Mean Value Stability", "description": "The mean value of the '
#  'column **predict_automatch** is 0.63. The expected range is from -0.32 to '
#  '1.6", "status": "SUCCESS", "group": "data_quality", "parameters": '
#  '{"column_name": "predict_automatch", "n_sigmas": 2, "current_mean": 0.63, '
#  '"reference_mean": 0.64, "reference_std": 0.48}}, {"name": "Drift per '
#  'Feature", "description": "The drift score for the feature **prod_gr_id** is '
#  '0. The drift detection method is chi-square p_value. The drift detection '
#  'threshold is 0.05.", "status": "FAIL", "group": "data_drift", "parameters": '
#  '{"features": {"prod_gr_id": {"stattest": "chi-square p_value", "score": 0.0, '
#  '"threshold": 0.05, "data_drift": true}}}}], "summary": {"all_passed": false, '
#  '"total_tests": 25, "success_tests": 16, "failed_tests": 9, "by_status": '
#  '{"SUCCESS": 16, "FAIL": 9}}, "columns_info": {"utility_columns": {"date": '
#  'null, "id_column": null, "target": null, "prediction": null}, '
#  '"num_feature_names": ["class_acctual", "predict_automatch"], '
#  '"cat_feature_names": ["brand_id", "country_id_n", "delivery_type_id", '
#  '"period_end_date", "prod_gr_id", "retailer_id", "translated_when", '
#  '"week_number"], "datetime_feature_names": [], "target_names": null}}')

# %%
data_integrity_dataset_tests
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_30f923a69a4d444496bd4fa8ac695151 = {"name": "Test Suite", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "9", "label": "Tests"}, {"value": "9", "label": "Success"}, {"value": "0", "label": "Warning"}, {"value": "0", "label": "Fail"}, {"value": "0", "label": "Error"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "test_suite", "title": "", "size": 2, "id": "", "details": "", "alertsPosition": null, "alertStats": null, "params": {"tests": [{"title": "Number of Columns", "description": "The number of columns is 10. The test threshold is eq=10.", "state": "success", "details": {"parts": [{"id": "Number of Columns_0_number_of_column", "title": "", "type": "widget"}]}, "groups": {"test_group": "data_integrity", "test_type": "Number of Columns"}}, {"title": "Number of Rows", "description": "The number of rows is 100. The test threshold is eq=100 \u00b1 10.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "Number of Rows"}}, {"title": "Test Number Of Nulls", "description": "Number of nulls is 7. The test threshold is lt=14.", "state": "success", "details": {"parts": [{"id": "Test Number Of Nulls_2_number_of_nulls", "title": "", "type": "widget"}]}, "groups": {"test_group": "data_integrity", "test_type": "Test Number Of Nulls"}}, {"title": "Number of Constant Columns", "description": "The number of constant columns is 0. The test threshold is lte=1.", "state": "success", "details": {"parts": [{"id": "Number of Constant Columns_3_number_of_constant_cols", "title": "", "type": "widget"}]}, "groups": {"test_group": "data_integrity", "test_type": "Number of Constant Columns"}}, {"title": "Number of Empty Rows", "description": "Number of Empty Rows is 0. Test Threshold is eq=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "Number of Empty Rows"}}, {"title": "Number of Empty Columns", "description": "Number of Empty Columns is 0 Test Threshold is lte=0.", "state": "success", "details": {"parts": [{"id": "Number of Empty Columns_5_number_of_empty_columns", "title": "", "type": "widget"}]}, "groups": {"test_group": "data_integrity", "test_type": "Number of Empty Columns"}}, {"title": "Number of Duplicate Rows", "description": "The number of duplicate rows is 0. The test threshold is eq=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "Number of Duplicate Rows"}}, {"title": "Number of Duplicate Columns", "description": "The number of duplicate columns is 0. The test threshold is lte=0.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "Number of Duplicate Columns"}}, {"title": "Column Types", "description": "The number of columns with a type mismatch is 0 out of 10.", "state": "success", "details": {"parts": [{"id": "Column Types_8_drift_table", "title": "", "type": "widget"}]}, "groups": {"test_group": "data_integrity", "test_type": "Column Types"}}], "testGroupTypes": [{"id": "by_feature", "title": "By feature", "values": [{"id": "no group", "title": "Dataset-level tests", "description": "Some tests cannot be grouped by feature", "sort_index": 0, "severity": null}]}, {"id": "test_group", "title": "By test group", "values": [{"id": "no group", "title": "Ungrouped", "description": "Some tests don\u2019t belong to any group under the selected condition", "sort_index": 0, "severity": null}, {"id": "data_drift", "title": "Data Drift", "description": "", "sort_index": 0, "severity": null}, {"id": "data_integrity", "title": "Data Integrity", "description": "", "sort_index": 0, "severity": null}, {"id": "data_quality", "title": "Data Quality", "description": "", "sort_index": 0, "severity": null}, {"id": "regression", "title": " ...
#     var additional_graphs_evidently_dashboard_30f923a69a4d444496bd4fa8ac695151 = {"Number of Columns_0_number_of_column": {"type": "table", "title": "", "size": 2, "id": "", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["column name", "current dtype", "reference dtype"], "data": [["brand_id", "object", "object"], ["class_acctual", "float64", "float64"], ["country_id_n", "object", "object"], ["delivery_type_id", "object", "object"], ["period_end_date", "datetime64[ns, UTC]", "datetime64[ns, UTC]"], ["predict_automatch", "float64", "float64"], ["prod_gr_id", "object", "object"], ["retailer_id", "object", "object"], ["translated_when", "datetime64[ns, UTC]", "datetime64[ns, UTC]"], ["week_number", "object", "object"]]}, "insights": [], "additionalGraphs": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, "Test Number Of Nulls_2_number_of_nulls": {"type": "table", "title": "", "size": 2, "id": "", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["column name", "current number of nulls", "reference number of nulls"], "data": [["predict_automatch", "3 (3.00%)", "0 (0.00%)"], ["country_id_n", "2 (2.00%)", "7 (7.00%)"], ["delivery_type_id", "2 (2.00%)", "7 (7.00%)"], ["period_end_date", "0 (0.00%)", "0 (0.00%)"], ["translated_when", "0 (0.00%)", "0 (0.00%)"], ["prod_gr_id", "0 (0.00%)", "0 (0.00%)"], ["retailer_id", "0 (0.00%)", "0 (0.00%)"], ["brand_id", "0 (0.00%)", "0 (0.00%)"], ["class_acctual", "0 (0.00%)", "0 (0.00%)"], ["week_number", "0 (0.00%)", "0 (0.00%)"]]}, "insights": [], "additionalGraphs": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, "Number of Constant Columns_3_number_of_constant_cols": {"type": "table", "title": "", "size": 2, "id": "", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["column name", "current nunique", "reference nunique"], "data": [["class_acctual", "2", "2"], ["predict_automatch", "2", "2"], ["week_number", "2", "1"], ["prod_gr_id", "3", "3"], ["period_end_date", "6", "2"], ["country_id_n", "11", "7"], ["delivery_type_id", "24", "15"], ["retailer_id", "36", "35"], ["translated_when", "59", "88"], ["brand_id", "62", "69"]]}, "insights": [], "additionalGraphs": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, "Number of Empty Columns_5_number_of_empty_columns": {"type": "table", "title": "", "size": 2, "id": "", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["column name", "current number of NaNs", "reference number of NaNs"], "data": [["predict_automatch", "3", "0"], ["country_id_n", "2", "7"], ["delivery_type_id", "2", "7"], ["brand_id", "0", "0"], ["class_acctual", "0", "0"], ["period_end_date", "0", "0"], ["prod_gr_id", "0", "0"], ["retailer_id", "0", "0"], ["translated_when", "0", "0"], ["week_number", "0", "0"]]}, "insights": [], "additionalGraphs": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, "Column Types_8_drift_table": {"type": "table", "title": "", "size": 2, "id": "", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Column Name", "Actual Type", "Expected Type"], "data": [["brand_id", "object_", "object_"], ["class_acctual", "float64", "float64"], ["country_id_n", "object_", "object_"], ["delivery_type_id", "object_", "object_"], ["period_end_date", "Timestamp",
